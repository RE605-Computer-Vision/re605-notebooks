# %% [markdown]
# # Tutorial Load Image Menggunakan OpenCV dan Python

# %%
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img = cv.imread("../images/cat-image.jpg")
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
plt.imshow(img_rgb)

# %%
img_rgb_2 = img[:,:,::-1]

# %%
plt.imshow(img_rgb_2)

# %%
img_rgb_2[10, 10, 0]
# Out:
# 14

# %%
img_rgb_2[10, 5, 1]
# Out:
# 33
